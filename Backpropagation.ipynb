# %%
import numpy as np
import math

# Entrada
entrada = np.array(
    [
        [2, 2, 3, 3],
        [1, 2, 3, 3],
        [2, 1, 4, 1],
        [1, 1, 4, 2],
        [1, 1, 3, 4],
        [1, 1, 3, 1],
        [1, 1, 3, 2]
    ]
)

# Salida
objetivo = np.array([0, 0, 1, 1, 0, 1, 1])

# Función sigmoidal
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

sig = np.vectorize(sigmoid)

# Inicialización de pesos y sesgos en la capa oculta
w_oculta = np.array(
    [[0.05, 0.3, 0.55], [0.1, 0.35, 0.6], [0.15, 0.4, 0.65], [0.2, 0.45, 0.7]]
)

b_oculta = np.array([[0.25, 0.5, 0.75]])

# Inicialización de pesos y sesgos en la capa de salida
w_salida = np.array(
    [
        [0.8],
        [0.85],
        [0.9],
    ]
)

b_salida = np.array([[0.95]])

lr = 0.5  # Tasa de aprendizaje
epocas = 200  # Número de épocas de entrenamiento
a = 1  # Variable auxiliar para seguimiento de épocas

for epoca in range(epocas):
    print("época    : ", a)
    prediccion = np.zeros(objetivo.shape)

    for idx, inp in enumerate(entrada):
        # Alimentación hacia adelante (feedforward)

        o_oculta = np.matmul(entrada[idx], w_oculta) + b_oculta
        o_oculta = sig(o_oculta)

        o_salida = np.matmul(o_oculta, w_salida) + b_salida
        o_salida = sig(o_salida)

        error = (objetivo[idx] - o_salida) ** 2
        prediccion[idx] = o_salida.round()

        print(
            "Entrada    :",
            entrada[idx],
            "   || Objetivo    :",
            objetivo[idx],
            "   || Predicción     :",
            math.trunc(prediccion[idx]),
            "   || Error   :",
            error,
        )

        # Retropropagación (backpropagation)
        w_salida = w_salida - lr * (-2 * (objetivo[idx] - o_salida)) * (
            o_salida * (1 - o_salida)
        ) * (o_oculta.T)
        b_salida = b_salida - lr * (-2 * (objetivo[idx] - o_salida)) * (
            o_salida * (1 - o_salida)
        ) * (1)

        w_oculta = (
            w_oculta
            - lr
            * ((-2 * (objetivo[idx] - o_salida)) * (o_salida * (1 - o_salida)))
            * (w_salida.T)
            * (o_oculta * (1 - o_oculta))
            * entrada[idx][np.newaxis].T
        )

        b_oculta = b_oculta - lr * (
            (-2 * (objetivo[idx] - o_salida)) * (o_salida * (1 - o_salida))
        ) * (w_salida.T) * (o_oculta * (1 - o_oculta)) * (1)

    a = a + 1
    print("---\n")
# Out:
# época    :  1
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.93361382]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.9245646]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00211643]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00199799]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.91613682]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00300904]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00272118]]
# ---
#
# época    :  2
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.90462646]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.88721723]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00526224]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00491797]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.87027217]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00786401]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00709913]]
# ---
#
# época    :  3
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.8477296]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.80872258]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.01802067]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.01604102]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.7755686]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02709531]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02325755]]
# ---
#
# época    :  4
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.7370567]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.64996295]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.07343455]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.05599884]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.62209318]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.08681752]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0651803]]
# ---
#
# época    :  5
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.59908415]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.46864392]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.17984087]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.11982875]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.49988344]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.15609047]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.10753385]]
# ---
#
# época    :  6
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.51763518]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.37771672]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.24442436]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.15903967]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.44638557]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.18999158]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.12804374]]
# ---
#
# época    :  7
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.4861415]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0.34561131]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 0    || Error   : [[0.26732704]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.17362599]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 1    || Error   : [[0
]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02444952]]
# ---
#
# época    :  62
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01690823]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01925666]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00532728]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00599375]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01098576]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00555562]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02372564]]
# ---
#
# época    :  63
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01634966]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01872647]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00517295]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00581999]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01068992]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00538669]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02303992]]
# ---
#
# época    :  64
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01582412]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01822191]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00502652]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00565537]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01040846]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00522666]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02238955]]
# ---
#
# época    :  65
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01532883]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01774129]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00488741]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00549919]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01014038]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00507489]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02177197]]
# ---
#
# época    :  66
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01486136]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.01728305]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00475508]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00535084]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00988477]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00493076]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.02118487]]
# ---
#
# época    :  67
# ...
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00292965]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00391368]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00084515]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00109139]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00226235]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00093016]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0046734]]
# ---
#
# época    :  180
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00290646]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00388402]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00083617]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00108167]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00224461]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00092207]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00463878]]
# ---
#
# época    :  181
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00288359]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00385477]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00082733]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00107209]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.0022271]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0009141]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00460466]]
# ---
#
# época    :  182
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00286105]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.0038259]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00081862]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00106265]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00220982]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00090626]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00457102]]
# ---
#
# época    :  183
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00283882]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00379741]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00081005]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00105333]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00219276]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00089853]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00453785]]
# ---
#
# época    :  184
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.0028169]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.0037693]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0008016]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00104415]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00217592]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00089092]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00450515]]
# ---
#
# época    :  185
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00279528]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00374156]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00079328]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00103509]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00215929]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00088342]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0044729]]
# ---
#
# época    :  186
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00277395]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00371418]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00078508]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00102616]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00214287]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00087604]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00444109]]
# ---
#
# época    :  187
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00275291]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00368716]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00077701]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00101736]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00212667]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00086876]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00440972]]
# ---
#
# época    :  188
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00273215]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00366048]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00076906]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00100867]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00211066]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00086159]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00437878]]
# ---
#
# época    :  189
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00271167]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00363415]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00076123]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0010001]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00209486]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00085452]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00434826]]
# ---
#
# época    :  190
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00269147]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00360814]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00075351]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00099165]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00207925]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00084756]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00431815]]
# ---
#
# época    :  191
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00267153]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00358247]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00074591]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00098332]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00206383]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00084069]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00428845]]
# ---
#
# época    :  192
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00265185]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00355712]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00073842]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0009751]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00204861]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00083393]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00425914]]
# ---
#
# época    :  193
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00263243]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00353209]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00073105]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00096699]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00203357]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00082726]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00423022]]
# ---
#
# época    :  194
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00261326]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00350737]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00072378]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00095899]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00201871]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00082069]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00420168]]
# ---
#
# época    :  195
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00259434]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00348296]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00071662]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00095109]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00200403]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00081421]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00417352]]
# ---
#
# época    :  196
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00257566]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00345884]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00070956]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0009433]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00198953]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00080782]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00414572]]
# ---
#
# época    :  197
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00255722]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00343503]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00070261]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00093562]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00197521]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00080152]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00411829]]
# ---
#
# época    :  198
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00253902]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.0034115]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00069576]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00092804]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00196105]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00079531]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.0040912]]
# ---
#
# época    :  199
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00252104]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00338825]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00068901]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00092056]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00194707]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00078918]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00406447]]
# ---
#
# época    :  200
# Entrada    : [2 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00250329]]
# Entrada    : [1 2 3 3]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00336529]]
# Entrada    : [2 1 4 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00068236]]
# Entrada    : [1 1 4 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00091317]]
# Entrada    : [1 1 3 4]    || Objetivo    : 0    || Predicción     : 0    || Error   : [[0.00193325]]
# Entrada    : [1 1 3 1]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00078314]]
# Entrada    : [1 1 3 2]    || Objetivo    : 1    || Predicción     : 1    || Error   : [[0.00403807]]
# ---
